# %% [markdown]
# ### Task Name : Exploratoey Data Analysis on Terrorism Dataset

# %% [markdown]
# ## Author:Tushar Dalvi

# %% [markdown]
# ### Dataset : https://drive.google.com/file/d/1luTU7xBvI7QAGPbQMxEHcgKUi9d6UeP_/view

# %% [markdown]
# ### Task Level : Intermediate

# %% [markdown]
# ### Importing Liabraries

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ### Importing the data set

# %%
df = pd.read_csv("C:/Users/HP/Downloads/Global Terrorism - START data/globalterrorismdb_0718dist.csv")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### To Display first five rows

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### To Display column names

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# ### Checking the null Values

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.describe().transpose()['max']
# Out:
# eventid      2.017123e+11
# iyear        2.017000e+03
# imonth       1.200000e+01
# iday         3.100000e+01
# extended     1.000000e+00
#                  ...
# nreleased    2.769000e+03
# INT_LOG      1.000000e+00
# INT_IDEO     1.000000e+00
# INT_MISC     1.000000e+00
# INT_ANY      1.000000e+00
# Name: max, Length: 77, dtype: float64

# %% [markdown]
# ### To get statistical info

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df = df.dropna(axis=1)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt  vicinity  ...  \
# 0       2  Central America & Caribbean         0  ...
# 1       1                North America         0  ...
# 2       5               Southeast Asia         0  ...
# 3       8               Western Europe         0  ...
# 4       4                    East Asia         0  ...
#
#                                 gname  individual  weaptype1  weaptype1_txt  \
# 0                              MANO-D           0         13        Unknown
# ...

# %% [markdown]
# ### Visualization
# ### Histogram

# %%
plt.figure(figsize = (20,5), dpi=200)
sns.histplot(df, x='country_txt')
plt.show()

# %%
df.groupby('country_txt').count()
# Out:
#              eventid  iyear  imonth   iday  extended  country  region  \
# country_txt
# Afghanistan    12731  12731   12731  12731     12731    12731   12731
# Albania           80     80      80     80        80       80      80
# Algeria         2743   2743    2743   2743      2743     2743    2743
# Andorra            1      1       1      1         1        1       1
# Angola           499    499     499    499       499      499     499
# ...              ...    ...     ...    ...       ...      ...     ...
# Yemen           3347   3347    3347   3347      3347     3347    3347
# Yugoslavia       203    203     203    203       203      203     203
# Zaire             50     50      50     50        50       50      50
# Zambia            62     62      62     62        62       62      62
# Zimbabwe         101    101     101    101       101      101     101
#
#              region_txt  vicinity  crit1  ...  gname  individual  weaptype1  \
# ...

# %%
country_count = df["country_txt"].value_counts()

# %%
country_count.head(20)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: country_txt, dtype: int64

# %%
country_count.to_csv('filel.csv')

# %%
most_terror = pd.read_csv('filel.csv')

# %% [markdown]
# ### Most Terror 5 Countries

# %%
most_terror.head()
# Out:
#     Unnamed: 0  country_txt
# 0         Iraq        24636
# 1     Pakistan        14368
# 2  Afghanistan        12731
# 3        India        11960
# 4     Colombia         8306

# %%
most_terror.rename(columns={'Unnamed: 0':'Country','country_txt':'Terror_count'}, inplace =True )

# %%
most_terror1 = most_terror.head(20)
most_terror1
# Out:
#            Country  Terror_count
# 0             Iraq         24636
# 1         Pakistan         14368
# 2      Afghanistan         12731
# 3            India         11960
# 4         Colombia          8306
# 5      Philippines          6908
# 6             Peru          6096
# 7      El Salvador          5320
# 8   United Kingdom          5235
# 9           Turkey          4292
# 10         Somalia          4142
# 11         Nigeria          3907
# 12        Thailand          3849
# 13           Yemen          3347
# 14           Spain          3249
# 15       Sri Lanka          3022
# 16   United States          2836
# 17         Algeria          2743
# 18          France          2693
# 19           Egypt          2479

# %%
plt.figure(figsize =(10,4), dpi=200)
plt.scatter(data = most_terror1, x='Country', y='Terror_count', marker ='D')
plt.xticks(rotation = 90)
plt.xlabel('Country')
plt.ylabel('Number of Terrorist activity')
plt.title('Top 20 terrorism hot zones')
plt.show()

# %% [markdown]
# ### Thank You
